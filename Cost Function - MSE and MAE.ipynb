# %%
from sklearn.metrics import mean_squared_error

y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
mse = mean_squared_error(y_true, y_pred)
print("MSE: %f\n" % mse)


y_true = [[0.5, 1],[-1, 1],[7, -6]]
y_pred = [[0, 2],[-1, 2],[8, -5]]
mse = mean_squared_error(y_true, y_pred)
print("MSE: %f\n" % mse)

 
mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')

print("MSE: {}\n".format(mse))

mse = mean_squared_error(y_true, y_pred, multioutput=[0.3, 0.7])

print("MSE: %f\n" % mse)

from sklearn.metrics import mean_absolute_error

y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
mae = mean_absolute_error(y_true, y_pred)
print("MAE: %f\n" % mae)


y_true = [[0.5, 1], [-1, 1], [7, -6]]
y_pred = [[0, 2], [-1, 2], [8, -5]]
mae = mean_absolute_error(y_true, y_pred)print("MAE: %f\n" % mae)

 
mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')

print("MAE: {}\n".format(mae))


mae = mean_absolute_error(y_true, y_pred, multioutput=[0.3, 0.7])

print("MAE: %f\n" % mae)
# Out:
#   File "<ipython-input-5-596e009fff7e>", line 33
#     mae = mean_absolute_error(y_true, y_pred) print("MAE: %f\n" % mae)
#                                                   ^
# SyntaxError: invalid syntax
